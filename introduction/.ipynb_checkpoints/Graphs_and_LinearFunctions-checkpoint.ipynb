# %% [markdown]
# ### Graphs and Linear Functions
#
# Function of a single variable
# Linear functions
# Plotting graphs
# The slope of graphs
#
#
# 1. Functions of a single variable
# 2. Linear functions
# 3. Plotting a graph of a linear function
# 4. The slope of a graph

# %% [markdown]
# #### Function of a single variable
#
# $$  y=f(x) $$
# $$ y = x $$

# %%
f(x)=x
print(f(10))
print(f(8))
print(f(6))
print(f(4))
# Out:
# 10
# 8
# 6
# 4

# %%
plot(f(x),-15.0,15.0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=x+5
print(f(10))
print(f(8))
print(f(6))
print(f(4))
# Out:
# 15
# 13
# 11
# 9

# %%
plot(f(x),-15.0,15.0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=x-5
print(f(10))
print(f(8))
print(f(6))
print(f(4))
# Out:
# 5
# 3
# 1
# -1

# %%
plot(f(x),-15.0,15.0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=2*x+5
print(f(10))
print(f(8))
print(f(6))
print(f(4))
# Out:
# 25
# 21
# 17
# 13

# %%
plot(f(x),-15.0,15.0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,m,c)=m*x+c
h(x)=f(x,5,5)


print(h(10))
print(h(8))
print(h(6))
print(h(4))
# Out:
# 55
# 45
# 35
# 25

# %%
plot(h(x),-15.0,15.0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# What happens when we vary the slope

# %%
@interact
def g(m=(-10..10),
      c=(-10..10)):
      h(x)=f(x,m,c),
      p1   = plot(h,-20, 20, thickness=4)
      show(p1, ymin=-20, ymax=20, xmin=-20, xmax=20)
# Out:
# SW50ZXJhY3RpdmUgZnVuY3Rpb24gPGZ1bmN0aW9uIGcgYXQgMHg2ZmUwM2FiMDQxMD4gd2l0aCAyIHdpZGdldHMKICBtOiBTZWxlY3Rpb25TbGlkZXIoZGVzY3JpcHRpb249dSdtJywgb3B0aW/igKY=

# %% [markdown]
# ## Further Help
#
# 1. [Math Planet - Algebra1](https://www.mathplanet.com/education/pre-algebra/graphing-and-functions/linear-equations-in-the-coordinate-plane)
